# %%
# Exp no 4

# %%
# Aim To Cal culate central Tendency of Measures

# %%
# Name; Srushti Gajanan Tade
# Roll No ; 62
# Sec : B 
# Subject :ET1 
# date ;

# %%
age=[22,21,20,20,21,21,21,21,22,20,20,21]

# %%
age
# Out:
# [22, 21, 20, 20, 21, 21, 21, 21, 22, 20, 20, 21]

# %%
import statistics

# %%
a= statistics.mean(age)

# %%
a
# Out:
# 20.833333333333332

# %%
b=statistics.median(age)

# %%
b
# Out:
# 21.0

# %%
c=statistics.mode(age)

# %%
c
# Out:
# 21

# %%
import numpy as np

# %%
x=np.array ([2,5,8,3,4,5,6,1,2,5,6])

# %%
x
# Out:
# array([2, 5, 8, 3, 4, 5, 6, 1, 2, 5, 6])

# %%
print(np.mean(x))
# Out:
# 4.2727272727272725

# %%
print (np.median(x))
# Out:
# 5.0

# %%
from scipy import stats

# %%
print (stats.mode(x))
# Out:
# ModeResult(mode=np.int64(5), count=np.int64(3))

# %%
std_dev=stats.tstd(x)

# %%
print(std_dev)
# Out:
# 2.101947149236112

# %%
v=stats.tvar(x)

# %%
v
# Out:
# np.float64(4.418181818181818)
