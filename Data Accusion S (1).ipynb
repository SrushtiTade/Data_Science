# %%
#Aim:To Perform Data Accusion

# %%
# Name :Srushti Gajanan Tade
#Roll No :16
# Sec :B 
# date:

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mohin\\ DSS_practical'

# %%
os.chdir('C:\\Users\\mohin\\OneDrive\\Desktop')

# %%
data=pd.read_csv("")
# Out:
#   Cell In[11], line 1
#     data=pd.read_csv("C:\Users\mohin\OneDrive\Desktop\diabetes.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
