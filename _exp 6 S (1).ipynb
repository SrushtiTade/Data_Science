# %%
# Exp no: 3

# %%
# Name : Srushti Gajanan Tade
# Roll no : 62
# SEC :B 
#Subject: ET1
#data :

# %%
# Basic of Data frame

# %% [markdown]
# # Creating a series

# %%
# importing the basic library

# %%
import pandas as pd

# %%
# creating student Name list

# %%
Name =["srushti " , "Ashvini","janhavi","yash ","shlok"]

# %%
Name
# Out:
# ['srushti ', 'Ashvini', 'janhavi', 'yash ', 'shlok']

# %%
Rolllist=pd.Series(Name,index=[1,2,3,4,5])

# %%
print(Rolllist)
# Out:
# 1    srushti
# 2     Ashvini
# 3     janhavi
# 4       yash
# 5       shlok
# dtype: object

# %% [markdown]
# # Creating a Data Frame

# %%
df=pd.DataFrame([[10,11,12,13],[14,15,16,17],[15,17,18,12],[20,27,26,13]],columns=["CD","DBMS","DSS","CAO"])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    11   12   13
# 1  14    15   16   17
# 2  15    17   18   12
# 3  20    27   26   13

# %%
df.shape
# Out:
# (4, 4)

# %%
df.size
# Out:
# 16

# %%
df.ndim
# Out:
# 2

# %%
df2=pd.DataFrame([[9,12,10,11]],columns=["CD","DBMS","DSS","CAO"])

# %%
df3=pd.concat([df,df2],ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    11   12   13
# 1  14    15   16   17
# 2  15    17   18   12
# 3  20    27   26   13
# 4   9    12   10   11

# %%
df3["DM"]=[11,12,13,14,15]

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    11   12   13  11
# 1  14    15   16   17  12
# 2  15    17   18   12  13
# 3  20    27   26   13  14
# 4   9    12   10   11  15

# %% [markdown]
# # Deleting Record(Row)Form Date Frame

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    11   12   13  11
# 2  15    17   18   12  13
# 3  20    27   26   13  14
# 4   9    12   10   11  15

# %%
print("Mean of DSS :",df4["DSS"].median())
# Out:
# Mean of DSS : 15.0

# %%
print("Mean of DSS :",df4["DSS"].mode())
# Out:
# Mean of DSS : 0    10
# 1    12
# 2    18
# 3    26
# Name: DSS, dtype: int64

# %%
print("Mean of DSS :",df4["DSS"].mode())
# Out:
# Mean of DSS : 0    10
# 1    12
# 2    18
# 3    26
# Name: DSS, dtype: int64

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    11   12   13  11
# 2  15    17   18   12  13
# 3  20    27   26   13  14
# 4   9    12   10   11  15
